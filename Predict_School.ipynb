# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %% [markdown]
# #### Load datasets

# %%
region_data = pd.read_csv('./data/salaries-by-region.csv')
college_type_data = pd.read_csv('./data/salaries-by-college-type.csv')

# %% [markdown]
# #### Display the first few rows of each dataset

# %%
region_data.head()
# Out:
#                                 School Name      Region  \
# 0                       Stanford University  California
# 1  California Institute of Technology (CIT)  California
# 2                       Harvey Mudd College  California
# 3        University of California, Berkeley  California
# 4                        Occidental College  California
#
#   Starting Median Salary Mid-Career Median Salary  \
# 0             $70,400.00              $129,000.00
# 1             $75,500.00              $123,000.00
# 2             $71,800.00              $122,000.00
# 3             $59,900.00              $112,000.00
# 4             $51,900.00              $105,000.00
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                        $68,400.00                        $93,100.00
# 1                               NaN                       $104,000.00
# 2                               NaN                        $96,000.00
# 3                        $59,500.00                        $81,000.00
# 4                               NaN                        $54,800.00
#
#   Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 0                       $184,000.00                       $257,000.00
# 1                       $161,000.00                               NaN
# 2                       $180,000.00                               NaN
# 3                       $149,000.00                       $201,000.00
# 4                       $157,000.00                               NaN

# %%
college_type_data.head()
# Out:
#                                     School Name  School Type  \
# 0   Massachusetts Institute of Technology (MIT)  Engineering
# 1      California Institute of Technology (CIT)  Engineering
# 2                           Harvey Mudd College  Engineering
# 3  Polytechnic University of New York, Brooklyn  Engineering
# 4                                  Cooper Union  Engineering
#
#   Starting Median Salary Mid-Career Median Salary  \
# 0             $72,200.00              $126,000.00
# 1             $75,500.00              $123,000.00
# 2             $71,800.00              $122,000.00
# 3             $62,400.00              $114,000.00
# 4             $62,200.00              $114,000.00
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                        $76,800.00                        $99,200.00
# 1                               NaN                       $104,000.00
# 2                               NaN                        $96,000.00
# 3                        $66,800.00                        $94,300.00
# 4                               NaN                        $80,200.00
#
#   Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 0                       $168,000.00                       $220,000.00
# 1                       $161,000.00                               NaN
# 2                       $180,000.00                               NaN
# 3                       $143,000.00                       $190,000.00
# 4                       $142,000.00                               NaN

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Checking for missing values

# %%
region_data.isnull().sum()
# Out:
# School Name                           0
# Region                                0
# Starting Median Salary                0
# Mid-Career Median Salary              0
# Mid-Career 10th Percentile Salary    47
# Mid-Career 25th Percentile Salary     0
# Mid-Career 75th Percentile Salary     0
# Mid-Career 90th Percentile Salary    47
# dtype: int64

# %%
college_type_data.isnull().sum()
# Out:
# School Name                           0
# School Type                           0
# Starting Median Salary                0
# Mid-Career Median Salary              0
# Mid-Career 10th Percentile Salary    38
# Mid-Career 25th Percentile Salary     0
# Mid-Career 75th Percentile Salary     0
# Mid-Career 90th Percentile Salary    38
# dtype: int64

# %% [markdown]
# #### Fill or drop missing values if necessary

# %%
region_data.dropna(inplace=True)
college_type_data.dropna(inplace=True)

# %% [markdown]
# #### Verify the conversion

# %%
region_data.dtypes
# Out:
# School Name                          object
# Region                               object
# Starting Median Salary               object
# Mid-Career Median Salary             object
# Mid-Career 10th Percentile Salary    object
# Mid-Career 25th Percentile Salary    object
# Mid-Career 75th Percentile Salary    object
# Mid-Career 90th Percentile Salary    object
# dtype: object

# %%
college_type_data.dtypes
# Out:
# School Name                          object
# School Type                          object
# Starting Median Salary               object
# Mid-Career Median Salary             object
# Mid-Career 10th Percentile Salary    object
# Mid-Career 25th Percentile Salary    object
# Mid-Career 75th Percentile Salary    object
# Mid-Career 90th Percentile Salary    object
# dtype: object

# %% [markdown]
# #### Convert salary columns to numeric values

# %%
region_data['Starting Median Salary'] = region_data['Starting Median Salary'].str.replace('[\$,]', '', regex=True).astype(float)
region_data['Mid-Career Median Salary'] = region_data['Mid-Career Median Salary'].str.replace('[\$,]', '', regex=True).astype(float)
college_type_data['Starting Median Salary'] = college_type_data['Starting Median Salary'].str.replace('[\$,]', '', regex=True).astype(float)
college_type_data['Mid-Career Median Salary'] = college_type_data['Mid-Career Median Salary'].str.replace('[\$,]', '', regex=True).astype(float)

# %% [markdown]
# #### Basic statistics

# %%
region_data.describe()
# Out:
#        Starting Median Salary  Mid-Career Median Salary
# count              273.000000                273.000000
# mean             46365.201465              83747.619048
# std               6311.007952              14527.134974
# min              34800.000000              46600.000000
# 25%              42200.000000              73500.000000
# 50%              45300.000000              82400.000000
# 75%              48900.000000              91600.000000
# max              72200.000000             134000.000000

# %%
college_type_data.describe()
# Out:
#        Starting Median Salary  Mid-Career Median Salary
# count              231.000000                231.000000
# mean             45825.108225              82666.233766
# std               6120.434189              14016.294341
# min              34800.000000              43900.000000
# 25%              41950.000000              73050.000000
# 50%              44700.000000              81300.000000
# 75%              47650.000000              87850.000000
# max              72200.000000             134000.000000

# %% [markdown]
# ### EDA and Visualization

# %% [markdown]
# #### Salary Increase by Region

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Region', y='Starting Median Salary', data=region_data)
plt.title('Starting Median Salary by Region')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Region', y='Mid-Career Median Salary', data=region_data)
plt.title('Mid-Career Median Salary by Region')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Salary Increase by College Type

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='School Type', y='Starting Median Salary', data=college_type_data)
plt.title('Starting Median Salary by College Type')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='School Type', y='Mid-Career Median Salary', data=college_type_data)
plt.title('Mid-Career Median Salary by College Type')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Distribution of salary increase

# %%
plt.figure(figsize=(10, 6))
sns.histplot(region_data['Mid-Career Median Salary'] - region_data['Starting Median Salary'], kde=True)
plt.title('Distribution of Salary Increase by Region')
plt.xlabel('Salary Increase')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(college_type_data['Mid-Career Median Salary'] - college_type_data['Starting Median Salary'], kde=True)
plt.title('Distribution of Salary Increase by College Type')
plt.xlabel('Salary Increase')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Combine datasets into a single DataFrame for modeling

# %%
combined_data = pd.merge(region_data, college_type_data, on='School Name', how='inner')

# %% [markdown]
# #### Drop columns with suffix '_y' and rename columns with suffix '_x' to remove suffix

# %%
columns_to_drop = [col for col in combined_data.columns if col.endswith('_y')]
combined_data.drop(columns=columns_to_drop, inplace=True)

# Rename columns with suffix '_x'
combined_data.columns = [col.replace('_x', '') for col in combined_data.columns]

# %%
combined_data.dropna(inplace=True)

# %%
combined_data.sample(10)
# Out:
#                                          School Name        Region  \
# 123                               Clemson University      Southern
# 189    Wesleyan University (Middletown, Connecticut)  Northeastern
# 67                           University of Iowa (UI)    Midwestern
# 30                                University of Utah       Western
# 156              University of Central Florida (UCF)      Southern
# 75                        University of North Dakota    Midwestern
# 61                                  St. Olaf College    Midwestern
# 137               Tennessee Technological University      Southern
# 215  University of Massachusetts (UMass) - Dartmouth  Northeastern
# 120                 Louisiana State University (LSU)      Southern
#
#      Starting Median Salary  Mid-Career Median Salary  \
# 123                 48400.0                   86000.0
# 189                 46500.0                   97900.0
# 67                  44700.0                   83900.0
# 30                  45400.0                   83200.0
# 156                 42600.0                   71700.0
# 75                  44000.0                   80600.0
# 61                  45300.0                   86200.0
# 137                 46200.0                   80000.0
# 215                 43200.0                   77700.0
# 120                 46900.0                   87800.0
#
#     Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 123                        $50,500.00                        $61,800.00
# 189                        $42,000.00                        $62,500.00
# 67                         $43,300.00                        $61,100.00
# 30                         $43,000.00                        $58,400.00
# 156                        $39,500.00                        $51,500.00
# 75                         $43,400.00                        $56,400.00
# 61                         $41,300.00                        $61,000.00
# 137                        $42,100.00                        $62,600.00
# 215                        $43,300.00                        $56,200.00
# 120                        $43,700.00                        $61,300.00
#
#     Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary  \
# 123                       $111,000.00                       $150,000.00
# 189                       $126,000.00                       $215,000.00
# 67                        $116,000.00                       $163,000.00
# 30                        $116,000.00                       $148,000.00
# 156                        $98,400.00                       $125,000.00
# 75                        $111,000.00                       $157,000.00
# 61                        $120,000.00                       $185,000.00
# 137                        $99,500.00                       $121,000.00
# 215                       $107,000.00                       $132,000.00
# 120                       $120,000.00                       $165,000.00
#
#       School Type
# 123         State
# 189  Liberal Arts
# 67          Party
# 30          State
# 156         State
# 75          State
# 61   Liberal Arts
# 137   Engineering
# 215         State
# 120         Party

# %% [markdown]
# #### Data Cleaning and Feature Engineering

# %%
combined_data.to_csv("./data/combined_data.csv", index=False)

# %%
label_encoder = LabelEncoder()
combined_data['Region'] = label_encoder.fit_transform(combined_data['Region'])
combined_data['School Type'] = label_encoder.fit_transform(combined_data['School Type'])
combined_data['School Name'] = label_encoder.fit_transform(combined_data['School Name'])

scaler = StandardScaler()
combined_data[['Starting Median Salary', 'Mid-Career Median Salary']] = scaler.fit_transform(combined_data[['Starting Median Salary', 'Mid-Career Median Salary']])

# %% [markdown]
# #### Selecting features and target variable

# %%
features = combined_data[['Region', 'School Type', 'School Name', 'Starting Median Salary']]
target = combined_data['Mid-Career Median Salary']

# %% [markdown]
# #### Splitting the data

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, shuffle=True, random_state=42)

# %% [markdown]
# #### Linear Regression Model

# %%
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from xgboost import XGBRegressor

xgboost =  XGBRegressor()
xgboost.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# #### Deep Learning Model

# %%
deep_model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)
])
deep_model.compile(optimizer='adam', loss='mse')
deep_model.fit(X_train, y_train, epochs=50, batch_size=8, validation_split=0.2)
# Out:
# /home/bruisedwolf/tf-venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717419134.668800    2117 service.cc:145] XLA service 0x7f4da0003d40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1717419134.668848    2117 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 3070 Laptop GPU, Compute Capability 8.6
#  1/18 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - loss: 35.1674
# I0000 00:00:1717419135.338519    2117 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 9.8707 - val_loss: 2.5039
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3372 - val_loss: 0.8483
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6499 - val_loss: 1.2132
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6505 - val_loss: 0.7533
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6509 - val_loss: 0.9866
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8060 - val_loss: 0.8929
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6497 - val_loss: 0.3749
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5239 - val_loss: 0.4731
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3143 - val_loss: 0.3048
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2533 - val_loss: 0.2461
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2945 - val_loss: 0.2031
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2275 - val_loss: 0.9943
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4786 - val_loss: 0.2111
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2024 - val_loss: 0.3724
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1708 - val_loss: 0.2444
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1712 - val_loss: 0.2284
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2291 - val_loss: 0.5920
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3150 - val_loss: 0.1588
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2966 - val_loss: 0.2709
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2535 - val_loss: 0.1468
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2528 - val_loss: 0.1717
# Epoch 22/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2138 - val_loss: 0.1455
# Epoch 23/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1859 - val_loss: 0.2200
# Epoch 24/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2145 - val_loss: 0.3843
# Epoch 25/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2289 - val_loss: 0.1477
# Epoch 26/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1989 - val_loss: 0.1744
# Epoch 27/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1852 - val_loss: 0.1843
# Epoch 28/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2071 - val_loss: 0.3252
# Epoch 29/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3464 - val_loss: 0.2405
# Epoch 30/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3060 - val_loss: 0.1839
# Epoch 31/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1850 - val_loss: 0.1877
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1795 - val_loss: 0.1599
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2327 - val_loss: 0.2246
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2265 - val_loss: 0.3126
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2347 - val_loss: 0.2040
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2468 - val_loss: 0.4192
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2750 - val_loss: 0.1547
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2082 - val_loss: 0.1449
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2021 - val_loss: 0.1524
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1496 - val_loss: 0.2598
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1706 - val_loss: 0.2666
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1492 - val_loss: 0.1660
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1908 - val_loss: 0.1470
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1414 - val_loss: 0.2847
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2994 - val_loss: 0.1482
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2134 - val_loss: 0.1482
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1952 - val_loss: 0.2578
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2117 - val_loss: 0.3312
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2616 - val_loss: 0.2207
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1945 - val_loss: 0.3726

# %% [markdown]
# #### Model Evaluation

# %%
linear_pred = linear_model.predict(X_test)
linear_mse = mean_squared_error(y_test, linear_pred)
linear_r2 = r2_score(y_test, linear_pred)

deep_pred = deep_model.predict(X_test)
deep_mse = mean_squared_error(y_test, deep_pred)
deep_r2 = r2_score(y_test, deep_pred)

print(f"Linear Regression MSE: {linear_mse}")
print(f"Linear Regression R²: {linear_r2}")
print()
print(f"Deep Learning Model MSE: {deep_mse}")
print(f"Deep Learning Model R²: {deep_r2}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# Linear Regression MSE: 0.1124075541795869
# Linear Regression R²: 0.8717181891190964
#
# Deep Learning Model MSE: 0.1788148585831775
# Deep Learning Model R²: 0.7959328086187614

# %%
xgboost_pred = xgboost.predict(X_test)
xgboost_mse = mean_squared_error(y_test, linear_pred)
xgboost_r2 = r2_score(y_test, linear_pred)

# %%
print(f"XGBoost MSE: {xgboost_mse}")
print(f"XGBoost R²: {xgboost_r2}")
# Out:
# XGBoost MSE: 0.1124075541795869
# XGBoost R²: 0.8717181891190964

# %% [markdown]
# #### Prediction Function

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
import pandas as pd

# Initialize label encoders and fit them with necessary data
regions_all = ['California', 'Western', 'Midwestern', 'Southern', 'Northeastern']
school_types_all = ['Engineering', 'Party', 'Liberal Arts', 'Ivy League', 'State']
schools_all = [
    'New Mexico Institute of Mining and Technology (New Mexico Tech)',
    'Missouri State University (MSU)',
    'University of Oregon',
    'University of Kentucky (UK)',
    'University of Minnesota',
    'Harvard University'
]

label_encoder = LabelEncoder()
label_encoder.fit(regions_all + school_types_all + schools_all)  # Fit with all possible labels

scaler = StandardScaler()
scaler.fit([[0]])  # Fit scaler with dummy data

def predict_best_school(schools, regions, school_types):
    n = len(schools)
    regions = (regions * (n // len(regions) + 1))[:n]
    school_types = (school_types * (n // len(school_types) + 1))[:n]
    
    input_data = pd.DataFrame({
        'Region': label_encoder.transform(regions),
        'School Type': label_encoder.transform(school_types),
        'School Name': label_encoder.transform(schools),
        'Starting Median Salary': scaler.transform([[0]] * len(schools)).flatten()  # Dummy data for starting salary
    })
    predictions = linear_model.predict(input_data)
    deep_predictions = deep_model.predict(input_data)

    results = pd.DataFrame({
        'School': schools,
        'Predicted Mid-Career Salary (Linear)': predictions,
        'Predicted Mid-Career Salary (Deep)': deep_predictions.flatten()
    })
    best_schools = results.sort_values(by='Predicted Mid-Career Salary (Deep)', ascending=False)
    return best_schools

# Example usage
schools = [
    'New Mexico Institute of Mining and Technology (New Mexico Tech)',
    'Missouri State University (MSU)',
    'University of Oregon',
    'University of Kentucky (UK)',
    'University of Minnesota',
    'Harvard University'
]

regions = ['California', 'Western', 'Midwestern', 'Southern', 'Northeastern']
school_types = ['Engineering', 'Party', 'Liberal Arts', 'Ivy League', 'State']

best_school_predictions = predict_best_school(schools, regions, school_types)

best_school_predictions


import joblib

# Dump the linear_model as a pkl file
joblib.dump(linear_model, 'linear_model.pkl')

import pickle

with open('linear_model.pkl', 'wb') as file:
    pickle.dump(linear_model, file)

# Dump the deep_model as a pkl file
joblib.dump(deep_model, 'deep_model.pkl')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# ['deep_model.pkl']

# %%
# linear_model

print("Intercept:", linear_model.intercept_)
print("Coefficients:", linear_model.coef_)
# Out:
# Intercept: 0.045708625168236004
# Coefficients: [-7.46071032e-03 -2.82948039e-02  4.89749987e-04  8.99519391e-01]
